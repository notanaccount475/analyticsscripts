# %% [markdown]
# # Data Load and Processing

# %% [markdown]
# ## Import raw data, rename cols

# %%
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.stats import ttest_ind, ttest_rel
from scipy.stats import pearsonr, spearmanr
from scipy.stats import f_oneway

# Load the sheet into a DataFrame (already done in this case)
df_master = pd.read_excel('MEC Compiled.xlsx', sheet_name='Sheet1')

df_master = df_master.dropna(how='all')

df_metadata = pd.read_excel('Metadata.xlsx', sheet_name='Sheet1')

# Create a dictionary mapping from the `Column` to `RENAME`
column_mapping = dict(zip(df_metadata['Column'], df_metadata['RENAME']))
df_master.rename(columns=column_mapping, inplace=True)

# %%
df_master[0:10]
# Out:
#    ID Group               Timestamp                          Email  \
# 0   1   Pre 2022-06-03 15:36:58.428      Smothekl@Sutterhealth.org
# 1   2   Pre 2022-06-03 15:51:52.673       mckinnr@sutterhealth.org
# 2   3   Pre 2022-06-10 21:10:02.732       grossmf@sutterhealth.org
# 3   4   Pre 2022-06-14 12:51:01.751           mbutcher@dpmginc.com
# 4   5   Pre 2022-06-14 15:05:38.538        abatem@sutterhealth.org
# 5   6   Pre 2022-06-14 17:40:26.038        FalcoD@sutterhealth.org
# 6   7   Pre 2022-06-15 11:08:18.492       Jerwers@sutterhealth.org
# 7   8   Pre 2022-06-15 13:53:09.095       piyarar@sutterhealth.org
# 8   9   Pre 2022-06-17 14:37:43.319      schaefmh@sutterhealth.org
# 9  10   Pre 2022-06-20 16:51:10.250  carrieann.drenten@vituity.com
#
#   TookSurveyLastYear CompassionateCarePatients CompassionateCareColleagues  \
# 0                NaN          Completely Agree            Completely Agree
# 1                NaN          Completely Agree              Somewhat Agree
# 2                NaN            Somewhat Agree                Mostly Agree
# 3                NaN          Completely Agree            Completely Agree
# 4                NaN            Somewhat Agree                Mostly Agree
# 5                NaN          Completely Agree                Mostly Agree
# 6                NaN              Mostly Agree                Mostly Agree
# 7                NaN            Somewhat Agree                Mostly Agree
# 8                NaN              Mostly Agree                Mostly Agree
# 9                NaN              Mostly Agree                Mostly Agree
#
#      EmpathyPriority EmpathyMissionStatement  SupportedMission  ...  Gender  \
# 0   Completely Agree        Completely Agree      Mostly Agree  ...    Male
# 1     Somewhat Agree        Completely Agree      Mostly Agree  ...  Female
# 2   Completely Agree        Completely Agree  Completely Agree  ...  Female
# 3   Completely Agree        Completely Agree  Completely Agree  ...  Female
# 4     Somewhat Agree        Completely Agree  Completely Agree  ...    Male
# 5  Somewhat Disagree            Mostly Agree  Completely Agree  ...    Male
# 6       Mostly Agree            Mostly Agree      Mostly Agree  ...    Male
# 7       Mostly Agree        Completely Agree    Somewhat Agree  ...    Male
# 8       Mostly Agree        Completely Agree  Completely Agree  ...    Male
# 9   Completely Agree        Completely Agree      Mostly Agree  ...  Female
#
#                HispanicBinary                       Race       Age  \
# 0  No, Not Hispanic or Latino  Black or African-American  65 to 74
# 1  No, Not Hispanic or Latino                      White  35 to 44
# 2  No, Not Hispanic or Latino                      White  45 to 54
# 3  No, Not Hispanic or Latino                      White  35 to 44
# 4  No, Not Hispanic or Latino                      White  55 to 64
# 5  No, Not Hispanic or Latino                      White  55 to 64
# 6  No, Not Hispanic or Latino                      White  45 to 54
# 7  No, Not Hispanic or Latino                      Asian  35 to 44
# 8  No, Not Hispanic or Latino                      White  65 to 74
# 9  No, Not Hispanic or Latino                      White  35 to 44
#
#   UnderstandFellowTeammateWork AskingHelpIneffective GivingHelpIdle  \
# 0                          NaN                   NaN            NaN
# 1                          NaN                   NaN            NaN
# 2                          NaN                   NaN            NaN
# 3                          NaN                   NaN            NaN
# 4                          NaN                   NaN            NaN
# 5                          NaN                   NaN            NaN
# 6                          NaN                   NaN            NaN
# 7                          NaN                   NaN            NaN
# 8                          NaN                   NaN            NaN
# 9                          NaN                   NaN            NaN
#
#   OfferHelpTool AssertSafetyConcern PersonalConflicts
# 0           NaN                 NaN               NaN
# 1           NaN                 NaN               NaN
# 2           NaN                 NaN               NaN
# 3           NaN                 NaN               NaN
# 4           NaN                 NaN               NaN
# 5           NaN                 NaN               NaN
# 6           NaN                 NaN               NaN
# 7           NaN                 NaN               NaN
# 8           NaN                 NaN               NaN
# 9           NaN                 NaN               NaN
#
# [10 rows x 47 columns]

# %% [markdown]
# ## Numerical Conversion

# %%
# Likert mapping for climate questions
likert_mapping = {
    "Completely Agree": 7,
    "Mostly Agree": 6,
    "Somewhat Agree": 5,
    "Slightly Agree": 5,
    "Unsure": 4,
    "Somewhat Disagree": 3,
    "Disagree Somewhat": 3,
    "Mostly Disagree": 2,
    "Completely Disagree": 1
}

# Specify the exact columns to convert
columns_to_convert = [
    'CompassionateCarePatients','CompassionateCareColleagues','EmpathyPriority','EmpathyMissionStatement','SupportedMission',
    'WalkthroughdoorsCaring','CuriosityAndOpenness','StressedAndPressed','LikeWorkingHere','FindsTimeNeeded','AdminInterference'
]

# Ensure all values are strings before cleaning
for col in columns_to_convert:
    df_master[col] = df_master[col].astype(str).str.strip()

# Apply Likert mapping
for col in columns_to_convert:
    df_master[col] = df_master[col].map(likert_mapping)

# Convert columns to numeric
for col in columns_to_convert:
    df_master[col] = pd.to_numeric(df_master[col], errors='coerce')

# %%
# Reverse the scale for StressedAndPressed and AdminInterference
df_master['StressedAndPressed'] = df_master['StressedAndPressed'].apply(lambda x: 8 - x if pd.notna(x) else x)
df_master['AdminInterference'] = df_master['AdminInterference'].apply(lambda x: 8 - x if pd.notna(x) else x)

df_master.rename(columns={
    'StressedAndPressed': 'StressedAndPressed_NOT',
    'AdminInterference': 'AdminInterference_NOT'
}, inplace=True)

# %%
df_master.iloc[0:10,4:13]
# Out:
#   TookSurveyLastYear  CompassionateCarePatients  CompassionateCareColleagues  \
# 0                NaN                          7                            7
# 1                NaN                          7                            5
# 2                NaN                          5                            6
# 3                NaN                          7                            7
# 4                NaN                          5                            6
# 5                NaN                          7                            6
# 6                NaN                          6                            6
# 7                NaN                          5                            6
# 8                NaN                          6                            6
# 9                NaN                          6                            6
#
#    EmpathyPriority  EmpathyMissionStatement  SupportedMission  \
# 0                7                        7                 6
# 1                5                        7                 6
# 2                7                        7                 7
# 3                7                        7                 7
# 4                5                        7                 7
# 5                3                        6                 7
# 6                6                        6                 6
# 7                6                        7                 5
# 8                6                        7                 7
# 9                7                        7                 6
#
#    WalkthroughdoorsCaring     MatchEyeLevel  CuriosityAndOpenness
# 0                     NaN  Completely Agree                     6
# 1                     5.0    Somewhat Agree                     3
# 2                     5.0  Completely Agree                     5
# 3                     7.0  Completely Agree                     7
# 4                     5.0  Completely Agree                     6
# 5                     6.0      Mostly Agree                     6
# 6                     6.0      Mostly Agree                     6
# 7                     6.0    Somewhat Agree                     6
# 8                     6.0  Completely Agree                     6
# 9                     3.0      Mostly Agree                     6

# %%
# learning mapping
learning_mapping = {
    "Yes, I definitely learned this": 4,
    "YES, definitely learned this here": 4,
    "Completely Agree": 4,
    "Strongly Agree": 4,
    "Mostly Agree": 4,
    "Somewhat Agree": 3,
    "No, but I heard something about": 3,
    "NO, but I heard something about this": 3,
    "Agree": 3,
    "Unsure": 2,
    "Neither  Nor Dis": 2,
    "Neither Agree Nor Disagree": 2,
    "No, and I know nothing about this": 1,
    "NO, and I know nothing about this": 1,
    "Disagree": 1,
    "Strongly Disagree": 1
    
}

# Specify the exact columns to convert
columns_to_convert = [
    'EyeContact','IDNeedExplanation',
    'AskTellAskLearned','AskQuestions',
    'ChallengeTechniques','EmpathicBridge',
    'MatchEyeLevel','TeachBackMethod',
    'NotRushed','HearComplaintConcern',
    'TakeAMoment','EmotionalStateAwareness',
    'VentFrustration','MinimizeTechnicalLanguage',
    'BadNewsDelivery'
]
# Ensure all values are strings before cleaning
for col in columns_to_convert:
    df_master[col] = df_master[col].astype(str).str.strip()
# Apply Likert mapping
for col in columns_to_convert:
    df_master[col] = df_master[col].map(learning_mapping)

# %%
df_master.iloc[0:10,10:20]
# Out:
#    WalkthroughdoorsCaring  MatchEyeLevel  CuriosityAndOpenness  \
# 0                     NaN              4                     6
# 1                     5.0              3                     3
# 2                     5.0              4                     5
# 3                     7.0              4                     7
# 4                     5.0              4                     6
# 5                     6.0              4                     6
# 6                     6.0              4                     6
# 7                     6.0              3                     6
# 8                     6.0              4                     6
# 9                     3.0              4                     6
#
#    StressedAndPressed_NOT  LikeWorkingHere  FindsTimeNeeded  \
# 0                       3                6                5
# 1                       1                6                5
# 2                       1                5                3
# 3                       3                6                5
# 4                       3                6                6
# 5                       5                6                5
# 6                       3                6                6
# 7                       6                6                5
# 8                       3                6                6
# 9                       1                6                3
#
#    AdminInterference_NOT  EyeContact  IDNeedExplanation  AskTellAskLearned
# 0                      2           3                  3                  3
# 1                      1           1                  3                  1
# 2                      4           4                  3                  1
# 3                      2           1                  2                  2
# 4                      5           3                  4                  4
# 5                      2           1                  4                  4
# 6                      6           4                  4                  4
# 7                      2           4                  3                  3
# 8                      2           1                  4                  4
# 9                      2           4                  4                  1

# %%
# TTPQ
learning_mapping = {
    "Strongly Agree": 5,
    "Agree": 4,
    "Disagree": 2,
    "Strongly Disagree": 1
    
}

# Specify the exact columns to convert
columns_to_convert = [
'UnderstandFellowTeammateWork',
'AskingHelpIneffective',
'GivingHelpIdle',
'OfferHelpTool',
'AssertSafetyConcern',
'PersonalConflicts'
]
# Ensure all values are strings before cleaning
for col in columns_to_convert:
    df_master[col] = df_master[col].astype(str).str.strip()
# Apply Likert mapping
for col in columns_to_convert:
    df_master[col] = df_master[col].map(learning_mapping)

# %%
# TTPQ Reversals
df_master['AskingHelpIneffective'] = df_master['AskingHelpIneffective'].apply(lambda x: 6 - x if pd.notna(x) else x)
df_master['GivingHelpIdle'] = df_master['GivingHelpIdle'].apply(lambda x: 6 - x if pd.notna(x) else x)
df_master['PersonalConflicts'] = df_master['PersonalConflicts'].apply(lambda x: 6 - x if pd.notna(x) else x)

df_master.rename(columns={
    'AskingHelpIneffective': 'AskingHelpIneffective_NOT',
    'GivingHelpIdle': 'GivingHelpIdle_NOT',
    'PersonalConflicts': 'PersonalConflicts_NOT'
}, inplace=True)

# %%
df_master.iloc[25:35,40:45]
# Out:
#       Age  UnderstandFellowTeammateWork  AskingHelpIneffective_NOT  \
# 25  45-54                           NaN                        NaN
# 26  55-64                           NaN                        NaN
# 27  45-54                           5.0                        5.0
# 28  45-54                           5.0                        4.0
# 29  45-54                           4.0                        5.0
# 30  45-54                           5.0                        4.0
# 31  45-54                           5.0                        5.0
# 32  35-44                           5.0                        5.0
# 33  55-64                           4.0                        4.0
#
#     GivingHelpIdle_NOT  OfferHelpTool
# 25                 NaN            NaN
# 26                 NaN            NaN
# 27                 5.0            5.0
# 28                 4.0            4.0
# 29                 5.0            4.0
# 30                 5.0            5.0
# 31                 5.0            4.0
# 32                 5.0            5.0
# 33                 4.0            4.0

# %% [markdown]
# ## Category Normalization

# %%
df_master['Race_normalized'] = df_master['Race'].str.strip().replace({
    'Asian': 'Asian',
    'White\xa0': 'White',
    'White':'White',
    'Black or African-American': 'Other',
    'Other\xa0': 'Other',
    'Pakistani': 'Asian',
    'Native Hawaiian or Pacific Islander': 'Asian',
    'White, Asian' :'Other',
    'Asian, Afghan': 'Asian'  
})

df_master['Age_normalized'] = df_master['Age'].str.strip().replace({
    '18-24': 'Gen Z',
    '25-34': 'Gen Z/Millenials',
    '35-44': 'Millenials', 
    '35 to 44': 'Millenials',
    '45-54': 'Gen X',
    '45 to 54': 'Gen X',
    '55-64': 'Senior',
    '55 to 64': 'Senior',
    '65-74': 'Senior',
    '65 to 74': 'Senior',
})

# %%
#course counts
exclude_mapping = {
    "Course 1-6": 6,
    "Course 1-3": 3,
    "Course 1-3; 6": 4,
    "Course 1, 2, 3": 3,
    "Course 1, Course 2, Course 3": 3,
    "I did not participate in any E-Learning courses.;": 0
}
# Create a new column to count semicolons with specific handling for exclude cases
df_master['CourseCount'] = df_master['CoursesCompleted'].apply(
    lambda x: exclude_mapping[x.strip()] if pd.notna(x) and x.strip() in exclude_mapping 
    else (x.strip().count(';') if pd.notna(x) else 0)
)



# Workshop counts
exclude_mapping = {
    "Workshop 1-3; Self-Empathy": 4,
    "Workshop 1-6; Self-Empathy": 7,
    "Workshop 1-3": 3,
    "Workshop 1-3; 6": 4,
    "I did not participate in any workshops.;": 0
}
# Create a new column to count semicolons with specific handling for exclude cases
df_master['WorkshopCount'] = df_master['WorkshopsCompleted'].apply(
    lambda x: exclude_mapping[x.strip()] if pd.notna(x) and x.strip() in exclude_mapping 
    else (x.strip().count(';') if pd.notna(x) else 0)
)

# %%
# Set the display option to wrap text
pd.set_option('display.max_colwidth', None)

# Display unique values for WorkshopsCompleted and WorkshopCount
df_master[['WorkshopsCompleted', 'WorkshopCount']].drop_duplicates()
#df_master[['CoursesCompleted', 'CourseCount']].drop_duplicates()
# Out:
#                                                                                                                                    WorkshopsCompleted  \
# 0                                                                                                                                          Self-Care;
# 2                                                                                                                                                 NaN
# 6                                                                                                                                           Course 1;
# 13                                                                                                                                Course 1; Course 2;
# 14                                                                                                                               Course 1; Self-Care;
# 19  Course 3. Delivering Bad News;Self-Empathy Workshop ;Course 2. Managing Difficult Medical Interactions;Course 1. Enhancing Empathy in Healthcare;
# 20                         Course 1. Enhancing Empathy in Healthcare;Course 2. Managing Difficult Medical Interactions;Course 3. Delivering Bad News;
# 22  Course 1. Enhancing Empathy in Healthcare;Course 2. Managing Difficult Medical Interactions;Course 3. Delivering Bad News;Self-Empathy Workshop ;
# 26                                                    Self-Empathy Workshop ;Course 3. Delivering Bad News;Course 1. Enhancing Empathy in Healthcare;
# 27  Course 1. Enhancing Empathy in Healthcare;Course 3. Delivering Bad News;Self-Empathy Workshop ;Course 2. Managing Difficult Medical Interactions;
# 29                                Course 1. Enhancing Empathy in Healthcare;Course 2. Managing Difficult Medical Interactions;Self-Empathy Workshop ;
# 32                                                                                                         Course 1. Enhancing Empathy in Healthcare;
#
#     WorkshopCount
# 0               1
# 2               0
# 6               1
# 13              2
# 14              2
# 19              4
# 20              3
# 22              4
# 26              3
# 27              4
# 29              3
# 32              1

# %%
#df_master['CourseCount'].value_counts()

#filtered_df = df_master[df_master['WorkshopCount'] == 2]
#print(filtered_df[['WorkshopsCompleted', 'WorkshopCount']])

# %%
# Define the logic for LearningSubgroup
def determine_learning_subgroup(row): 
    if row['CourseCount'] >= 3 and row['WorkshopCount'] >= 1:
        return "Fully Trained"
    elif row['CourseCount'] >= 1 and row['WorkshopCount'] >= 1:
        return "1+ course, 1+ workshop" 
    elif row['CourseCount'] >= 2 and row['WorkshopCount'] == 0:
        return "2+ courses, no workshop" 
    elif row['CourseCount'] == 0 and row['WorkshopCount'] > 0:
        return "No courses, >0 workshop"
    elif row['CourseCount'] < 2 and row['WorkshopCount'] < 1:
        return "No training"
    else:
        return 'No Category'  # For cases that don't match any condition (optional)

# Apply the logic to create the new column
df_master['LearningSubgroup'] = df_master.apply(determine_learning_subgroup, axis=1)

# %%
df_master.LearningSubgroup.value_counts()

# Set the display option to wrap text
pd.set_option('display.max_colwidth', None)

# Display unique values for WorkshopsCompleted and WorkshopCount
df_master[['CourseCount','WorkshopCount','LearningSubgroup']].drop_duplicates()
# Out:
#     CourseCount  WorkshopCount         LearningSubgroup
# 0             0              1  No courses, >0 workshop
# 2             0              0              No training
# 3             1              0              No training
# 13            2              2   1+ course, 1+ workshop
# 14            1              2   1+ course, 1+ workshop
# 15            1              1   1+ course, 1+ workshop
# 18            2              1   1+ course, 1+ workshop
# 19            3              4            Fully Trained
# 20            3              3            Fully Trained
# 21            4              3            Fully Trained
# 22            0              4  No courses, >0 workshop
# 24            5              4            Fully Trained
# 29            2              3   1+ course, 1+ workshop

# %%
#filtered_df = df_master[df_master['LearningSubgroup'] == 'No Category']

#filtered_df[['CoursesCompleted', 'CourseCount','WorkshopsCompleted', 'WorkshopCount']]

# %%
"""
#df_master[['CourseCount', 'WorkshopCount','LearningSubgroup']].value_counts()

# Get the value counts for the selected columns
value_counts = df_master[['CourseCount', 'WorkshopCount', 'LearningSubgroup']].value_counts()

# Convert the value counts to a DataFrame
value_counts_df = value_counts.reset_index()
value_counts_df.columns = ['CourseCount', 'WorkshopCount', 'LearningSubgroup', 'Count']

# Display the DataFrame as a table
print(value_counts_df)
"""
# Out:
# "\n#df_master[['CourseCount', 'WorkshopCount','LearningSubgroup']].value_counts()\n\n# Get the value counts for the selected columns\nvalue_counts = df_master[['CourseCount', 'WorkshopCount', 'LearningSubgroup']].value_counts()\n\n# Convert the value counts to a DataFrame\nvalue_counts_df = value_counts.reset_index()\nvalue_counts_df.columns = ['CourseCount', 'WorkshopCount', 'LearningSubgroup', 'Count']\n\n# Display the DataFrame as a table\nprint(value_counts_df)\n"

# %%
# Create the ExposureGroup column
df_master['ExposureGroup'] = df_master.apply(
    lambda row: 'N' if row['CourseCount'] == 0 and row['WorkshopCount'] == 0 else 'Y',
    axis=1
)

# %%
df_master = df_master[df_master['Group'] != 'Pre']
df_master
# Out:
#     ID   Group           Timestamp      Email TookSurveyLastYear  \
# 19  20  Post 1 2024-01-18 18:43:00  anonymous                Yes
# 20  21  Post 1 2024-01-18 19:41:00  anonymous                Yes
# 21  22  Post 1 2024-01-19 00:59:00  anonymous                 No
# 22  23  Post 1 2024-01-19 11:59:00  anonymous             Unsure
# 23  24  Post 1 2024-01-21 12:07:00  anonymous                Yes
# 24  25  Post 1 2024-01-22 22:58:00  anonymous                 No
# 25  26  Post 1 2024-01-26 15:23:00  anonymous                 No
# 26  27  Post 1 2024-02-03 15:16:00  anonymous                Yes
# 27  28  Post 2 2025-02-14 12:09:00  anonymous                 No
# 28  29  Post 2 2025-02-14 13:09:00  anonymous                 No
# 29  30  Post 2 2025-02-14 14:24:00  anonymous                Yes
# 30  31  Post 2 2025-02-15 13:36:00  anonymous                 No
# 31  32  Post 2 2025-02-16 18:08:00  anonymous             Unsure
# 32  33  Post 2 2025-03-05 15:06:00  anonymous                 No
# 33  34  Post 2 2025-03-05 16:39:00  anonymous                 No
#
#     CompassionateCarePatients  CompassionateCareColleagues  EmpathyPriority  \
# 19                          6                            7                6
# 20                          6                            7                3
# 21                          7                            7                6
# 22                          7                            7                6
# 23                          6                            6                6
# 24                          7                            7                2
# 25                          6                            6                7
# 26                          7                            6                5
# 27                          6                            6                6
# 28                          7                            7                6
# 29                          6                            5                5
# 30                          7                            7                7
# 31                          7                            4                4
# 32                          6                            6                5
# 33                          7                            6                6
#
#     EmpathyMissionStatement  SupportedMission  ...  GivingHelpIdle_NOT  \
# 19                        7                 7  ...                 NaN
# 20                        7                 6  ...                 NaN
# 21                        7                 7  ...                 NaN
# 22                        7                 6  ...                 NaN
# 23                        7                 7  ...                 NaN
# 24                        5                 2  ...                 NaN
# 25                        7                 6  ...                 NaN
# 26                        7                 7  ...                 NaN
# 27                        7                 7  ...                 5.0
# 28                        6                 6  ...                 4.0
# 29                        7                 7  ...                 5.0
# 30                        7                 7  ...                 5.0
# 31                        7                 4  ...                 5.0
# 32                        7                 6  ...                 5.0
# 33                        4                 7  ...                 4.0
#
#     OfferHelpTool  AssertSafetyConcern  PersonalConflicts_NOT  \
# 19            NaN                  NaN                    NaN
# 20            NaN                  NaN                    NaN
# 21            NaN                  NaN                    NaN
# 22            NaN                  NaN                    NaN
# 23            NaN                  NaN                    NaN
# 24            NaN                  NaN                    NaN
# 25            NaN                  NaN                    NaN
# 26            NaN                  NaN                    NaN
# 27            5.0                  5.0                    5.0
# 28            4.0                  5.0                    5.0
# 29            4.0                  5.0                    5.0
# 30            5.0                  5.0                    5.0
# 31            4.0                  5.0                    5.0
# 32            5.0                  4.0                    4.0
# 33            4.0                  4.0                    4.0
#
#     Race_normalized  Age_normalized  CourseCount  WorkshopCount  \
# 19            White           Gen X            3              4
# 20            White           Gen X            3              3
# 21            White      Millenials            4              3
# 22            Other          Senior            0              4
# 23            White          Senior            3              4
# 24            White           Gen X            5              4
# 25            White           Gen X            3              4
# 26            White          Senior            3              3
# 27            White           Gen X            3              4
# 28            White           Gen X            3              3
# 29            White           Gen X            2              3
# 30            White           Gen X            4              3
# 31            White           Gen X            3              4
# 32            Asian      Millenials            2              1
# 33            White          Senior            3              3
#
#            LearningSubgroup  ExposureGroup
# 19            Fully Trained              Y
# 20            Fully Trained              Y
# 21            Fully Trained              Y
# 22  No courses, >0 workshop              Y
# 23            Fully Trained              Y
# 24            Fully Trained              Y
# 25            Fully Trained              Y
# 26            Fully Trained              Y
# 27            Fully Trained              Y
# 28            Fully Trained              Y
# 29   1+ course, 1+ workshop              Y
# 30            Fully Trained              Y
# 31            Fully Trained              Y
# 32   1+ course, 1+ workshop              Y
# 33            Fully Trained              Y
#
# [15 rows x 53 columns]

# %% [markdown]
# ## Averaging

# %%
# List of columns to average
empathy_climate_cols = [
    'CompassionateCareColleagues',
    'CompassionateCarePatients',
    'EmpathyMissionStatement',
    'EmpathyPriority',
    'SupportedMission'
]

# Create the ClimateOfEmpathy_Avg column
df_master['ClimateOfEmpathy_Avg'] = df_master[empathy_climate_cols].mean(axis=1)
# Out:
# C:\Users\shlin\AppData\Local\Temp\ipykernel_33988\3502756136.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_master['ClimateOfEmpathy_Avg'] = df_master[empathy_climate_cols].mean(axis=1)

# %%
# List of columns to average for EmpathyLearning_Avg
empathy_learning_columns = [
'MatchEyeLevel',
'EyeContact',
'IDNeedExplanation',
'AskTellAskLearned',
'AskQuestions',
'ChallengeTechniques',
'EmpathicBridge',
'TeachBackMethod',
'NotRushed',
'HearComplaintConcern',
'TakeAMoment',
'EmotionalStateAwareness',
'VentFrustration',
'MinimizeTechnicalLanguage',
'BadNewsDelivery'
]

# Create the EmpathyLearning_Avg column
df_master['EmpathyLearning_Avg'] = df_master[empathy_learning_columns].mean(axis=1)
# Out:
# C:\Users\shlin\AppData\Local\Temp\ipykernel_33988\2354118593.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_master['EmpathyLearning_Avg'] = df_master[empathy_learning_columns].mean(axis=1)

# %%
# List of columns to average for GeneralClimate_Avg
general_climate_columns = [
    'AdminInterference_NOT',
    'CuriosityAndOpenness',
    'FindsTimeNeeded',
    'LikeWorkingHere',
    'StressedAndPressed_NOT',
    'WalkthroughdoorsCaring'
]

# Create the GeneralClimate_Avg column
df_master['GeneralClimate_Avg'] = df_master[general_climate_columns].mean(axis=1)
# Out:
# C:\Users\shlin\AppData\Local\Temp\ipykernel_33988\7240026.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_master['GeneralClimate_Avg'] = df_master[general_climate_columns].mean(axis=1)

# %%
# Create the OverallClimate_Avg column by averaging GeneralClimate_Avg and ClimateOfEmpathy_Avg
df_master['OverallClimate_Avg'] = df_master[['GeneralClimate_Avg', 'ClimateOfEmpathy_Avg']].mean(axis=1)
# Out:
# C:\Users\shlin\AppData\Local\Temp\ipykernel_33988\1765864871.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_master['OverallClimate_Avg'] = df_master[['GeneralClimate_Avg', 'ClimateOfEmpathy_Avg']].mean(axis=1)

# %%
#averages, median, std dev across all numerical cols

# %% [markdown]
# ## Save to xlsx

# %%
average_row = df_master.mean(numeric_only=True)

# Create a new DataFrame with the average row
df_average = pd.DataFrame(average_row).T
df_average.index = ['Average']

# Append the original DataFrame to the new DataFrame
df_new = pd.concat([df_master, df_average], ignore_index=False)

# Save the new DataFrame as an Excel file
output_file = "MEC_Processed.xlsx"
df_new.to_excel(output_file, index=False)

print(f"DataFrame saved as {output_file}")
# Out:
# DataFrame saved as MEC_Processed.xlsx

# %% [markdown]
# # Statistical Testing

# %% [markdown]
# ## Class Creation

# %%
class StatisticalAnalysis:
    def __init__(self, df):
        """
        Initialize the class with a DataFrame.
        """
        self.df = df

    def t_test_by_group(self, group_column, group1, group2):
        unique_groups = self.df[group_column].dropna().unique()
        if group1 not in unique_groups or group2 not in unique_groups:
            raise ValueError(f"Both '{group1}' and '{group2}' must be present in the column '{group_column}'.")

        print(f"Group 1: {group1} (first group in the t-test)")
        print(f"Group 2: {group2} (second group in the t-test)")
        print("Interpretation:")
        print(" - A positive t-statistic means the mean of the first group is greater than the mean of the second group.")
        print(" - A negative t-statistic means the mean of the first group is less than the mean of the second group.")
        print("\nT-Test Results:\n")

        numeric_columns = self.df.select_dtypes(include='number').columns
        group1_mask = self.df[group_column] == group1
        group2_mask = self.df[group_column] == group2

        t_test_results = {}
        for col in numeric_columns:
            group1_values = self.df.loc[group1_mask, col].dropna()
            group2_values = self.df.loc[group2_mask, col].dropna()
            t_stat, p_value = ttest_ind(group1_values, group2_values, equal_var=False)

            t_test_results[col] = {'t_stat': t_stat, 'p_value': p_value}

        t_test_results_df = pd.DataFrame(t_test_results).T.sort_values(by='p_value')
        t_test_results_df['Group1'] = group1
        t_test_results_df['Group2'] = group2

        return t_test_results_df

    def anova_by_group(self, group_column):
        unique_groups = self.df[group_column].dropna().unique()
        if len(unique_groups) < 2:
            raise ValueError(f"The column '{group_column}' must have at least two unique groups.")

        print(f"Groups: {', '.join(map(str, unique_groups))} (categories in the ANOVA test)")
        print("Interpretation:")
        print(" - The F-statistic measures the ratio of variation between group means to variation within groups.")
        print(" - A high F-statistic suggests larger differences between group means relative to within-group variability.")
        print("\nANOVA Results:\n")

        numeric_columns = self.df.select_dtypes(include='number').columns
        anova_results = {}
        for col in numeric_columns:
            group_means = {
                group: self.df.loc[self.df[group_column] == group, col].mean() for group in unique_groups
            }

            group_values = [self.df.loc[self.df[group_column] == group, col].dropna() for group in unique_groups]
            f_stat, p_value = f_oneway(*group_values)

            sorted_groups = sorted(group_means.items(), key=lambda x: x[1], reverse=True)
            highest_group, highest_mean = sorted_groups[0]

            anova_results[col] = {
                'f_stat': f_stat,
                'p_value': p_value,
                'highest_group': highest_group,
                'highest_mean': highest_mean,
                'group_means': group_means
            }

        anova_results_df = pd.DataFrame(anova_results).T.sort_values(by='p_value')
        anova_results_df['Groups'] = ', '.join(map(str, unique_groups))

        return anova_results_df

    def correlation_with_column(self, target_column):
        if target_column not in self.df.select_dtypes(include='number').columns:
            raise ValueError(f"Target column '{target_column}' is not numeric or does not exist in the DataFrame.")

        numeric_columns = [col for col in self.df.select_dtypes(include='number').columns if col != target_column]
        correlation_results = {}

        for col in numeric_columns:
            valid_data = self.df[[target_column, col]].dropna()

            if len(valid_data) < 2:
                correlation_results[col] = {
                    'correlation_coefficient': None,
                    'p_value': None,
                    'interpretation': "Not enough data to calculate correlation."
                }
                continue

            corr, p_value = pearsonr(valid_data[target_column], valid_data[col])

            correlation_results[col] = {
                'correlation_coefficient': corr,
                'p_value': p_value
            }
        correlation_results_df = pd.DataFrame(correlation_results).T.sort_values(by='correlation_coefficient', key=abs, ascending=False)
        return correlation_results_df

# %% [markdown]
# ## Initialization/Testing

# %%
analysis = StatisticalAnalysis(df_master)

# %%
analysis.anova_by_group('Race_normalized')
# Out:
# Groups: White, Other, Asian (categories in the ANOVA test)
# Interpretation:
#  - The F-statistic measures the ratio of variation between group means to variation within groups.
#  - A high F-statistic suggests larger differences between group means relative to within-group variability.
#
# ANOVA Results:
# C:\Users\shlin\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: ConstantInputWarning: Each of the input arrays is constant; the F statistic is not defined or infinite
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\shlin\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:4102: DegenerateDataWarning: at least one input has length 0
#   if _f_oneway_is_too_small(samples):
#                                  f_stat   p_value highest_group highest_mean  \
# WorkshopCount                 11.333333   0.00172         Other          4.0
# CourseCount                   10.107317  0.002672         White     3.230769
# GeneralClimate_Avg             2.295516  0.143168         Other     6.666667
# OverallClimate_Avg             1.825182  0.203208         Other     6.633333
# ID                             1.378378  0.289162         Asian         33.0
# LikeWorkingHere                1.222222  0.328763         Other          7.0
# StressedAndPressed_NOT         1.126904  0.356043         Other          6.0
# EmpathyLearning_Avg            0.985928  0.401387         Other     3.933333
# FindsTimeNeeded                0.933333  0.420006         Other          7.0
# CompassionateCarePatients      0.933333  0.420006         Other          7.0
# WalkthroughdoorsCaring         0.745946  0.495051         Other          7.0
# CuriosityAndOpenness           0.709677  0.511326         Other          7.0
# AdminInterference_NOT          0.694737  0.518211         Other          6.0
# BadNewsDelivery                0.597015  0.566008         Other          4.0
# VentFrustration                0.462857  0.640266         Other          4.0
# CompassionateCareColleagues    0.364179  0.702188         Other          7.0
# AskTellAskLearned              0.355556  0.707924         Other          4.0
# EmpathicBridge                 0.268493  0.769004         White     3.538462
# ClimateOfEmpathy_Avg           0.253717   0.77997         Other          6.6
# NotRushed                          0.24  0.790315         Other          4.0
# EmpathyMissionStatement         0.19726  0.823586         Other          7.0
# ChallengeTechniques            0.157143  0.856467         Other          4.0
# IDNeedExplanation              0.145455  0.866131         Other          4.0
# EyeContact                     0.128571  0.880546         Other          4.0
# EmpathyPriority                0.126437  0.882388         Other          6.0
# TeachBackMethod                0.071429  0.931491         Other          4.0
# HearComplaintConcern           0.066667  0.935851         Other          4.0
# TakeAMoment                    0.066667  0.935851         Other          4.0
# AskQuestions                   0.066667  0.935851         Other          4.0
# SupportedMission               0.008889  0.991157         White     6.153846
# MatchEyeLevel                       NaN       NaN         White          4.0
# EmotionalStateAwareness             NaN       NaN         White          4.0
# MinimizeTechnicalLanguage           NaN       NaN         White          4.0
# UnderstandFellowTeammateWork        NaN       NaN         White     4.666667
# AskingHelpIneffective_NOT           NaN       NaN         White          4.5
# GivingHelpIdle_NOT                  NaN       NaN         White     4.666667
# OfferHelpTool                       NaN       NaN         White     4.333333
# AssertSafetyConcern                 NaN       NaN         White     4.833333
# PersonalConflicts_NOT               NaN       NaN         White     4.833333
#
#                                                                                                        group_means  \
# WorkshopCount                                            {'White': 3.4615384615384617, 'Other': 4.0, 'Asian': 1.0}
# CourseCount                                               {'White': 3.230769230769231, 'Other': 0.0, 'Asian': 2.0}
# GeneralClimate_Avg            {'White': 5.423076923076922, 'Other': 6.666666666666667, 'Asian': 5.666666666666667}
# OverallClimate_Avg            {'White': 5.788461538461538, 'Other': 6.633333333333333, 'Asian': 5.833333333333334}
# ID                                                     {'White': 26.846153846153847, 'Other': 23.0, 'Asian': 33.0}
# LikeWorkingHere                                          {'White': 6.3076923076923075, 'Other': 7.0, 'Asian': 6.0}
# StressedAndPressed_NOT                                    {'White': 3.769230769230769, 'Other': 6.0, 'Asian': 5.0}
# EmpathyLearning_Avg           {'White': 3.771428571428572, 'Other': 3.933333333333333, 'Asian': 3.933333333333333}
# FindsTimeNeeded                                                         {'White': 6.0, 'Other': 7.0, 'Asian': 6.0}
# CompassionateCarePatients                                 {'White': 6.538461538461538, 'Other': 7.0, 'Asian': 6.0}
# WalkthroughdoorsCaring                                    {'White': 6.153846153846154, 'Other': 7.0, 'Asian': 6.0}
# CuriosityAndOpenness                                     {'White': 6.3076923076923075, 'Other': 7.0, 'Asian': 6.0}
# AdminInterference_NOT                                                   {'White': 4.0, 'Other': 6.0, 'Asian': 5.0}
# BadNewsDelivery                                           {'White': 3.230769230769231, 'Other': 4.0, 'Asian': 4.0}
# VentFrustration                                          {'White': 3.3076923076923075, 'Other': 4.0, 'Asian': 4.0}
# CompassionateCareColleagues                               {'White': 6.230769230769231, 'Other': 7.0, 'Asian': 6.0}
# AskTellAskLearned                                        {'White': 3.6923076923076925, 'Other': 4.0, 'Asian': 4.0}
# EmpathicBridge                                           {'White': 3.5384615384615383, 'Other': 3.0, 'Asian': 3.0}
# ClimateOfEmpathy_Avg                                      {'White': 6.153846153846154, 'Other': 6.6, 'Asian': 6.0}
# NotRushed                                                 {'White': 3.769230769230769, 'Other': 4.0, 'Asian': 4.0}
# EmpathyMissionStatement                                   {'White': 6.538461538461538, 'Other': 7.0, 'Asian': 7.0}
# ChallengeTechniques                                      {'White': 3.8333333333333335, 'Other': 4.0, 'Asian': 4.0}
# IDNeedExplanation                                        {'White': 3.8461538461538463, 'Other': 4.0, 'Asian': 4.0}
# EyeContact                                                {'White': 3.769230769230769, 'Other': 4.0, 'Asian': 4.0}
# EmpathyPriority                                          {'White': 5.3076923076923075, 'Other': 6.0, 'Asian': 5.0}
# TeachBackMethod                                          {'White': 3.9166666666666665, 'Other': 4.0, 'Asian': 4.0}
# HearComplaintConcern                                     {'White': 3.8461538461538463, 'Other': 4.0, 'Asian': 4.0}
# TakeAMoment                                               {'White': 3.923076923076923, 'Other': 4.0, 'Asian': 4.0}
# AskQuestions                                              {'White': 3.923076923076923, 'Other': 4.0, 'Asian': 4.0}
# SupportedMission                                          {'White': 6.153846153846154, 'Other': 6.0, 'Asian': 6.0}
# MatchEyeLevel                                                           {'White': 4.0, 'Other': 4.0, 'Asian': 4.0}
# EmotionalStateAwareness                                                 {'White': 4.0, 'Other': 4.0, 'Asian': 4.0}
# MinimizeTechnicalLanguage                                               {'White': 4.0, 'Other': 4.0, 'Asian': 4.0}
# UnderstandFellowTeammateWork                              {'White': 4.666666666666667, 'Other': nan, 'Asian': 5.0}
# AskingHelpIneffective_NOT                                               {'White': 4.5, 'Other': nan, 'Asian': 5.0}
# GivingHelpIdle_NOT                                        {'White': 4.666666666666667, 'Other': nan, 'Asian': 5.0}
# OfferHelpTool                                             {'White': 4.333333333333333, 'Other': nan, 'Asian': 5.0}
# AssertSafetyConcern                                       {'White': 4.833333333333333, 'Other': nan, 'Asian': 4.0}
# PersonalConflicts_NOT                                     {'White': 4.833333333333333, 'Other': nan, 'Asian': 4.0}
#
#                                            Groups
# WorkshopCount                 White, Other, Asian
# CourseCount                   White, Other, Asian
# GeneralClimate_Avg            White, Other, Asian
# OverallClimate_Avg            White, Other, Asian
# ID                            White, Other, Asian
# LikeWorkingHere               White, Other, Asian
# StressedAndPressed_NOT        White, Other, Asian
# EmpathyLearning_Avg           White, Other, Asian
# FindsTimeNeeded               White, Other, Asian
# CompassionateCarePatients     White, Other, Asian
# WalkthroughdoorsCaring        White, Other, Asian
# CuriosityAndOpenness          White, Other, Asian
# AdminInterference_NOT         White, Other, Asian
# BadNewsDelivery               White, Other, Asian
# VentFrustration               White, Other, Asian
# CompassionateCareColleagues   White, Other, Asian
# AskTellAskLearned             White, Other, Asian
# EmpathicBridge                White, Other, Asian
# ClimateOfEmpathy_Avg          White, Other, Asian
# NotRushed                     White, Other, Asian
# EmpathyMissionStatement       White, Other, Asian
# ChallengeTechniques           White, Other, Asian
# IDNeedExplanation             White, Other, Asian
# EyeContact                    White, Other, Asian
# EmpathyPriority               White, Other, Asian
# TeachBackMethod               White, Other, Asian
# HearComplaintConcern          White, Other, Asian
# TakeAMoment                   White, Other, Asian
# AskQuestions                  White, Other, Asian
# SupportedMission              White, Other, Asian
# MatchEyeLevel                 White, Other, Asian
# EmotionalStateAwareness       White, Other, Asian
# MinimizeTechnicalLanguage     White, Other, Asian
# UnderstandFellowTeammateWork  White, Other, Asian
# AskingHelpIneffective_NOT     White, Other, Asian
# GivingHelpIdle_NOT            White, Other, Asian
# OfferHelpTool                 White, Other, Asian
# AssertSafetyConcern           White, Other, Asian
# PersonalConflicts_NOT         White, Other, Asian

# %%
analysis.correlation_with_column('OverallClimate_Avg')
# Out:
# C:\Users\shlin\AppData\Local\Temp\ipykernel_33988\1330754246.py:93: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr, p_value = pearsonr(valid_data[target_column], valid_data[col])
# C:\Users\shlin\AppData\Local\Temp\ipykernel_33988\1330754246.py:93: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr, p_value = pearsonr(valid_data[target_column], valid_data[col])
# C:\Users\shlin\AppData\Local\Temp\ipykernel_33988\1330754246.py:93: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr, p_value = pearsonr(valid_data[target_column], valid_data[col])
#                               correlation_coefficient   p_value
# AdminInterference_NOT                    8.583330e-01  0.000042
# ClimateOfEmpathy_Avg                     7.340429e-01  0.001836
# UnderstandFellowTeammateWork             7.331232e-01  0.060833
# GeneralClimate_Avg                       7.293212e-01  0.002032
# EmpathyPriority                          7.140774e-01  0.002786
# OfferHelpTool                            6.097583e-01  0.146012
# ChallengeTechniques                      5.820114e-01  0.028993
# StressedAndPressed_NOT                   5.272076e-01  0.043436
# AskingHelpIneffective_NOT               -4.362498e-01  0.327812
# BadNewsDelivery                          4.189157e-01  0.120136
# EmpathyMissionStatement                  4.127181e-01  0.126293
# EmpathyLearning_Avg                      4.054354e-01  0.133799
# LikeWorkingHere                         -3.970498e-01  0.142811
# SupportedMission                         3.796700e-01  0.162770
# CourseCount                             -3.678591e-01  0.177340
# WalkthroughdoorsCaring                   3.649554e-01  0.181048
# AssertSafetyConcern                      3.529853e-01  0.437378
# PersonalConflicts_NOT                    3.529853e-01  0.437378
# VentFrustration                          3.389977e-01  0.216444
# AskQuestions                             3.260628e-01  0.235606
# CuriosityAndOpenness                     3.196026e-01  0.245558
# CompassionateCareColleagues              2.796231e-01  0.312810
# NotRushed                                2.590618e-01  0.351154
# CompassionateCarePatients                2.203311e-01  0.430066
# TakeAMoment                             -2.162383e-01  0.438896
# HearComplaintConcern                     1.521171e-01  0.588368
# TeachBackMethod                         -1.492093e-01  0.610679
# FindsTimeNeeded                          1.356500e-01  0.629784
# EmpathicBridge                          -1.069685e-01  0.704363
# EyeContact                              -8.199849e-02  0.771421
# GivingHelpIdle_NOT                       7.421741e-02  0.874351
# IDNeedExplanation                       -5.456035e-02  0.846864
# WorkshopCount                            3.774951e-02  0.893746
# AskTellAskLearned                       -1.462159e-02  0.958753
# ID                                       2.775558e-16  1.000000
# MatchEyeLevel                                     NaN       NaN
# EmotionalStateAwareness                           NaN       NaN
# MinimizeTechnicalLanguage                         NaN       NaN

# %%
def is_senior(age_group):
    senior_age_groups = ['Senior']
    return age_group in senior_age_groups

# Create a new column 'SeniorStatus'
df_master['SeniorStatus'] = df_master['Age_normalized'].apply(
    lambda x: 'Senior' if is_senior(x) else 'Non-Senior'
)

# %%
filtered_df = df_master[df_master['Gender'] != 'Prefer Not To Answer']
analysis = StatisticalAnalysis(filtered_df)
analysis.t_test_by_group('Gender', 'Female', 'Male')
# Out:
# Group 1: Female (first group in the t-test)
# Group 2: Male (second group in the t-test)
# Interpretation:
#  - A positive t-statistic means the mean of the first group is greater than the mean of the second group.
#  - A negative t-statistic means the mean of the first group is less than the mean of the second group.
#
# T-Test Results:
# C:\Users\shlin\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
#                                 t_stat   p_value  Group1 Group2
# StressedAndPressed_NOT       -4.692519  0.001134  Female   Male
# GeneralClimate_Avg           -2.901930  0.019188  Female   Male
# ID                           -1.786172  0.099461  Female   Male
# SupportedMission              1.875974  0.104748  Female   Male
# UnderstandFellowTeammateWork -2.000000  0.183503  Female   Male
# VentFrustration              -1.343122  0.209507  Female   Male
# CompassionateCarePatients    -1.305952  0.214366  Female   Male
# WalkthroughdoorsCaring       -1.279204  0.224030  Female   Male
# CourseCount                  -1.195208  0.253480  Female   Male
# FindsTimeNeeded              -1.180393  0.261700  Female   Male
# EmpathyLearning_Avg          -1.065307  0.308237  Female   Male
# AdminInterference_NOT        -1.055515  0.313640  Female   Male
# EmpathicBridge               -1.028812  0.328698  Female   Male
# BadNewsDelivery              -1.000000  0.340279  Female   Male
# AskQuestions                 -1.000000  0.350617  Female   Male
# TakeAMoment                   1.000000  0.355918  Female   Male
# HearComplaintConcern          1.000000  0.355918  Female   Male
# ClimateOfEmpathy_Avg          0.967811  0.361795  Female   Male
# TeachBackMethod               1.000000  0.363217  Female   Male
# OverallClimate_Avg           -0.826778  0.424025  Female   Male
# WorkshopCount                 0.800641  0.444989  Female   Male
# CuriosityAndOpenness         -0.555556  0.588114  Female   Male
# NotRushed                    -0.493197  0.630127  Female   Male
# CompassionateCareColleagues   0.481481  0.640014  Female   Male
# EmpathyPriority               0.464238  0.652833  Female   Male
# EyeContact                   -0.372104  0.716913  Female   Male
# AskingHelpIneffective_NOT     0.377964  0.722788  Female   Male
# OfferHelpTool                -0.377964  0.722788  Female   Male
# LikeWorkingHere               0.343672  0.736627  Female   Male
# GivingHelpIdle_NOT           -0.200000  0.851163  Female   Male
# AssertSafetyConcern          -0.200000  0.851163  Female   Male
# PersonalConflicts_NOT        -0.200000  0.851163  Female   Male
# AskTellAskLearned             0.144841  0.887142  Female   Male
# EmpathyMissionStatement       0.111933  0.912625  Female   Male
# IDNeedExplanation             0.094072  0.926549  Female   Male
# ChallengeTechniques           0.000000  1.000000  Female   Male
# MatchEyeLevel                      NaN       NaN  Female   Male
# EmotionalStateAwareness            NaN       NaN  Female   Male
# MinimizeTechnicalLanguage          NaN       NaN  Female   Male

# %%
analysis = StatisticalAnalysis(df_master)
analysis.t_test_by_group('SeniorStatus')

# %%
# Select only numeric columns
numeric_columns = df_master.select_dtypes(include='number').columns

# Group by 'Group' and calculate mean, median, and std for numeric columns
grouped_stats = df_master.groupby('Group')[numeric_columns].agg(['mean', 'median', 'std'])

# Save the results to an Excel file
output_file = "Group_Statistics.xlsx"
grouped_stats.to_excel(output_file)

print(f"Grouped statistics saved to {output_file}")
# Out:
# Grouped statistics saved to Group_Statistics.xlsx
